# %%
# Importing necessary Libraries.

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
len(sns.get_dataset_names())
# Out:
# 88

# %%
data = sns.load_dataset('iris')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
data['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Line Plot and Scatter Plot: Best suited for two continuous variables.

# %%
sns.lineplot(x='sepal_length',y='sepal_width',data=data,ci=None)    #ci - Confidence Interval - For example, if we say a 95% confidence interval for the mean is (50, 60), 
                                                                    #it means we are 95% confident that the true mean lies between 50 and 60. The percentage (like 95%) is the confidence level, which shows how sure we are about the interval.
plt.show()

# %%
sns.lineplot(x='sepal_length',y='sepal_width',hue='species',data=data,ci=None)
plt.legend(loc='lower right')
plt.title('Line Plot')
plt.plot()
# Out:
# []

# %%
# Continuous and categorical feature.
sns.lineplot(x='sepal_width',y='species',data=data,ci=None,hue='species')
plt.plot()
# Out:
# []

# %%
sns.lineplot(x='petal_length',y='species',data=data,hue='species')
plt.plot()
# Out:
# []

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=data,hue='species')
plt.title('Scatter Plot')
plt.plot()
# Out:
# []

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Bar Plot: One categorical and one continuous variable.

# %%
sns.barplot(x='species',y='sepal_length',data=data)
plt.title('Bar Plot')
plt.plot()
# Out:
# []

# %%
sns.countplot(x='species',data=data)
plt.title('Count Plot')
plt.plot()
# Out:
# []

# %% [markdown]
# All the 3 species of iris are of 50 counts.

# %%
sns.boxplot(x='sepal_width',data=data)
plt.title('Box Plot')
plt.plot()
# Out:
# []

# %%
Q1 = data['sepal_width'].quantile(0.25)
print(Q1)
Q3 = data['sepal_width'].quantile(0.75)
print(Q3)
# Out:
# 2.8
# 3.3

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 0.5

# %%
min_=Q1-1.5*IQR
max_=Q3+1.5*IQR
print(min_)
print(max_)
# Out:
# 2.05
# 4.05

# %%
print(data.loc[(data['sepal_width']<min_)])
print(data.loc[data['sepal_width']>max_])
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 60           5.0          2.0           3.5          1.0  versicolor
#     sepal_length  sepal_width  petal_length  petal_width species
# 15           5.7          4.4           1.5          0.4  setosa
# 32           5.2          4.1           1.5          0.1  setosa
# 33           5.5          4.2           1.4          0.2  setosa

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Checking the percentage of outlier in the dataset .
# If it is > 5% then we should not handle it
# If it is < 5% then only we should deal with it.

l = len(data.loc[data['sepal_width']>max_])+len(data.loc[data['sepal_width']<min_])

# %%
l/len(data)*100
# Out:
# 2.666666666666667

# %%
# 2.6 means the outliers should be handed.

# %%
# So now we will impute outliers using median

# %%
data.loc[data['sepal_width']>max_,'sepal_width'] = data['sepal_width'].median()

# %%
data.loc[data['sepal_width']>max_]
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
sns.boxplot(x='sepal_width',data=data)              # So now there are no outliers on the right side of the graph which means 
                                                    # We've imputed them in the range using outliers.
plt.plot                                            # Imputing means replacing outliers with mean value of given column.
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
data.loc[data['sepal_width']<min_]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 60           5.0          2.0           3.5          1.0  versicolor

# %%
data['sepal_width'].mean()
# Out:
# 3.0326666666666666

# %%
data.loc[data['sepal_width']<min_,'sepal_width']=data['sepal_width'].mean()

# %%
sns.boxplot(x='sepal_width',data=data)
plt.plot()
# Out:
# []

# %%
sns.boxplot(x='species',y='sepal_width',data=data)
plt.plot()
# Out:
# []

# %%
sns.histplot(x='petal_length',data=data,kde=True)    
plt.show()                              #(KDE)Kernel Density Estimate :-is used in a histplot to make the data's distribution smoother and easier to interpret.
                                        #Instead of showing data as bars (like in a histogram), KDE draws a smooth curve that represents the same distribution.

# %%
sns.histplot(x='petal_width',data=data,hue='species',kde=True)
plt.show()

# %%
sns.pairplot(data=data,hue='species')    #A pair plot is used to visualize relationships between multiple numerical variables in a dataset.
plt.show()
